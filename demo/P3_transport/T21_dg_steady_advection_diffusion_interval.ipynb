# %% [markdown]
# # DG steady advection-diffusion in an interval
#
# Donea, J. & Huerta, A. (2003). *Finite Element Methods for Flow Problems*. $\S 2.6.2$
#
# $$
# \mathbb{S}_u
# \begin{cases}
# \Omega = [0, 1] & \text{unit interval} \\
# u_{\text{D}}(x=0,)=0 \\
# u_{\text{D}}(x=1)=1 \\
# \textbf{a}=a\,\textbf{e}_x \\
# \mathsf{D}=D\mathsf{I} \\
# R=0 \\
# J=0 \\
# u_{\text{e}}(x)=... \\
# Pe= \frac{a}{2DN_x} & \text{local Peclet number} \\
# \end{cases}
# $$

# %%
import numpy as np
from ufl.core.expr import Expr
from ufl import SpatialCoordinate, as_vector, cos, sqrt
from lucifex.mesh import rectangle_mesh
from lucifex.fem import Function, Constant, cross_section
from lucifex.solver import bvp, BoundaryConditions, BoundaryValueProblem
from lucifex.plt import plot_colormap, plot_line, save_figure
from lucifex.pde.advection_diffusion import (
    steady_advection_diffusion, 
    dg_steady_advection_diffusion
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 from ufl import SpatialCoordinate, as_vector, cos, sqrt
#       4 from lucifex.mesh import rectangle_mesh
# ----> 5 from lucifex.fem import Function, Constant, cross_section
#       6 from lucifex.solver import bvp, BoundaryConditions, BoundaryValueProblem
#       7 from lucifex.plt import plot_colormap, plot_line, save_figure
#
# ImportError: cannot import name 'cross_section' from 'lucifex.fem' (/Users/George/Desktop/LUCiFEx/lucifex/fem/__init__.py)
