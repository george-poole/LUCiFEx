# %% [markdown]
# # SUPG steady advection-diffusion with a skew velocity
#
# Donea, J. & Huerta, A. (2003). *Finite Element Methods for Flow Problems*. $\S 2.6.4$
#
# $$
# \mathbb{S}_u
# \begin{cases}
# \Omega = [0, 1]\times[0,1] \\
# u_{\text{D}}(x=0,y<y_{\text{in}}) = 0 \\
# u_{\text{D}}(x=0,y \geq y_{\text{in}}) = u_{\text{in}} \\
# u_{\text{D}}(x,y=0) = 0 \\
# u_{\text{N}}(x,y=1)=u_{\text{D}}(x=1,y) = 0 ~\text{or}~ u_{\text{N}}(x,y=1)=u_{\text{N}}(x=1,y) = 0\\
# \textbf{a}=a\cos\theta\textbf{e}_x + a\sin\theta\textbf{e}_y \\
# \mathsf{D}=D\mathsf{I} \\
# R=0 \\
# J=0 \\
# \end{cases}
# $$

# %%
import numpy as np
from lucifex.mesh import rectangle_mesh
from lucifex.fem import Function, Constant
from lucifex.fdm import peclet
from lucifex.solver import BoundaryValueProblem, bvp, BoundaryConditions
from lucifex.plt import plot_colormap, save_figure
from lucifex.utils.py_utils import nested_dict
from lucifex.pde.advection_diffusion import steady_advection_diffusion


def create_solver(
    supg: str | None,
    Lx: float,
    Ly: float,
    Nx: int,
    Ny: int,
    u_inflow: float,
    y_inflow: float,
    bc_type: str,
    d: float, 
    a: float,
    theta: float,
) -> BoundaryValueProblem:
    mesh = rectangle_mesh(Lx, Ly, Nx, Ny)
    ax = a * np.cos(np.radians(theta))
    ay = a * np.sin(np.radians(theta))
    a = Constant(mesh, (ax, ay), name='a')
    d = Constant(mesh, d, name='d')
    u = Function((mesh, 'P', 1), name='u')
    bcs = BoundaryConditions(
        ('dirichlet', lambda x: x[1], 0.0),
        ('dirichlet', lambda x: np.isclose(x[0], 0) & (x[1] < y_inflow), 0.0),
        ('dirichlet', lambda x: np.isclose(x[0], 0) & (x[1] >= y_inflow), u_inflow),
        (bc_type, lambda x: x[0] - Lx, 0.0),
        (bc_type, lambda x: x[1] - Ly, 0.0),
    )
    u_solver = bvp(steady_advection_diffusion, bcs=bcs)(
        u, a, d, j=Constant(mesh, 0.0), supg=supg,
    )
    return u_solver


Lx = 1.0
Ly = 1.0
Nx = 20
Ny = 20
u_inflow = 1.0
y_inflow = 0.2
d = 1e-3
a = 1.0
theta = 30.0

hx = Lx / Nx
hy = Ly / Ny
Pe_x = peclet(hx, a, d)
Pe_y = peclet(hy, a, d)

supg_types = (None, 'coth', 'coth_infty')
bc_types = ('neumann', 'dirichlet')
solutions: dict[str | None, dict[str, Function]] = nested_dict(depth=2)
for supg in supg_types:
    for bc in bc_types:
        u_solver = create_solver(supg, Lx, Ly, Nx, Ny, u_inflow, y_inflow, bc, d, a, theta)
        u_solver.solve()
        solutions[supg][bc] = u_solver.solution
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 63
#      61 for supg in supg_types:
#      62     for bc in bc_types:
# ---> 63         u_solver = create_solver(supg, Lx, Ly, Nx, Ny, u_inflow, y_inflow, bc, d, a, theta)
#      64         u_solver.solve()
#      65         solutions[supg][bc] = u_solver.solution
#
# Cell In[1], line 37, in create_solver(supg, Lx, Ly, Nx, Ny, u_inflow, y_inflow, bc_type, d, a, theta)
#      29 u = Function((mesh, 'P', 1), name='u')
#      30 bcs = BoundaryConditions(
#      31     ('dirichlet', lambda x: x[1], 0.0),
#      32     ('dirichlet', lambda x: np.isclose(x[0], 0) & (x[1] < y_inflow), 0.0),
#    (...)
#      35     (bc_type, lambda x: x[1] - Ly, 0.0),
#      36 )
# ---> 37 u_solver = bvp(steady_advection_diffusion, bcs=bcs)(
#      38     u, a, d, j=Constant(mesh, 0.0), supg=supg,
#      39 )
#      40 return u_solver
#
# File ~/Desktop/LUCiFEx/lucifex/solver/pde.py:328, in BoundaryValueProblem.from_forms_factory.<locals>._create(*args, **kwargs)
#     324 if solution is None:
#     325     solution = _deduce_from_args(0, args, kwargs)
#     326 return cls(
#     327     solution,
# --> 328     forms_factory(*args, **kwargs),
#     329     bcs,
#     330     petsc,
#     331     jit,
#     332     ffcx,
#     333     corrector,
#     334     cache_matrix,
#     335     assemble_termwise,
#     336     pc_form,
#     337     future,
#     338     overwrite,
#     339 )
#
# TypeError: steady_advection_diffusion() got an unexpected keyword argument 'supg'

# %%
for bc in bc_types:
    for supg in supg_types:
        u = solutions[supg][bc]
        if supg is None:
            supg = 'unstabilized'
        title = f'{bc.capitalize()}-{supg}\n$u$'
        fig, ax = plot_colormap(u, title=title)
        thumbnail = (bc == 'neumann' and supg == 'coth')
        save_figure(f'u(x,y)_{bc}_{supg}', thumbnail=thumbnail)(fig)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 for bc in bc_types:
#       2     for supg in supg_types:
# ----> 3         u = solutions[supg][bc]
#       4         if supg is None:
#       5             supg = 'unstabilized'
#
# KeyError: 'neumann'
