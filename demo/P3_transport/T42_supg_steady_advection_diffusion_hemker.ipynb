# %% [markdown]
# # SUPG steady advection-diffusion of the Hemker problem
#
# Donea, J. & Huerta, A. (2003). *Finite Element Methods for Flow Problems*. $\S 2.6.6$
#
# $$
# \mathbb{S}_u
# \begin{cases}
# \Omega = [-1, 1] \\
# u_{\text{D}}(x=-1)=-2 \\
# u_{\text{D}}(x=1)=0 \\
# \textbf{a}=x\,\textbf{e}_x \\
# \mathsf{D}=-\nu\mathsf{I} \\
# R=0 \\
# J = -D\pi^2\cos(\pi x) -\pi x\sin(\pi x) \\
# u_{\text{e}}(x)=\cos(\pi x)+\frac{\text{erf}\left(\frac{x}{\sqrt{2D}}\right)}{\text{erf}\left(\frac{1}{\sqrt{2D}}\right)}
# \end{cases}
# $$

# %%
import numpy as np
import scipy.special as sp
from ufl import SpatialCoordinate, as_vector, cos, sin, CellDiameter
from lucifex.mesh import interval_mesh
from lucifex.fem import Function, Constant
from lucifex.solver import BoundaryValueProblem, bvp, BoundaryConditions
from lucifex.plt import plot_line, save_figure
from lucifex.utils.py_utils import nested_dict
from lucifex.pde.advection_diffusion import steady_advection_diffusion

def create_solver(
    supg: str | None,
    Nx: int,
    nu: float, 
    Lx: tuple[float, float] = (-1.0, 1.0),
    dirichlet: tuple[float, float] = (-2.0, 0.0),
) -> BoundaryValueProblem:
    mesh = interval_mesh(Lx, Nx)
    bcs = BoundaryConditions(
        ('dirichlet', lambda x: x[0] - Lx[0], dirichlet[0]),
        ('dirichlet', lambda x: x[0] - Lx[1], dirichlet[1])
    )
    x = SpatialCoordinate(mesh)
    a = as_vector((x[0], ))
    d = Constant(mesh, -nu, name='d')
    nu = Constant(mesh, nu, name='nu')
    j = -nu * np.pi**2 * cos(np.pi * x[0]) - np.pi * x[0] * sin(np.pi * x[0])
    u = Function((mesh, 'P', 1), name='u')
    h = CellDiameter(mesh)
    u_solver = bvp(steady_advection_diffusion, bcs=bcs)(
        u, a, d, j=j, supg=supg, h=h,
    )
    return u_solver


Lx = (-1.0, 1.0)
Nx = 20
nu = 1e-6
supg_opts = (None, 'coth')
solutions: dict[str | None, Function] = nested_dict()

for supg in supg_opts:
    u_solver = create_solver(supg, Nx, nu, Lx)
    u_solver.solve()
    solutions[supg] = u_solver.solution
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 43
#      40 solutions: dict[str | None, Function] = nested_dict()
#      42 for supg in supg_opts:
# ---> 43     u_solver = create_solver(supg, Nx, nu, Lx)
#      44     u_solver.solve()
#      45     solutions[supg] = u_solver.solution
#
# Cell In[1], line 30, in create_solver(supg, Nx, nu, Lx, dirichlet)
#      28 u = Function((mesh, 'P', 1), name='u')
#      29 h = CellDiameter(mesh)
# ---> 30 u_solver = bvp(steady_advection_diffusion, bcs=bcs)(
#      31     u, a, d, j=j, supg=supg, h=h,
#      32 )
#      33 return u_solver
#
# File ~/Desktop/LUCiFEx/lucifex/solver/pde.py:328, in BoundaryValueProblem.from_forms_factory.<locals>._create(*args, **kwargs)
#     324 if solution is None:
#     325     solution = _deduce_from_args(0, args, kwargs)
#     326 return cls(
#     327     solution,
# --> 328     forms_factory(*args, **kwargs),
#     329     bcs,
#     330     petsc,
#     331     jit,
#     332     ffcx,
#     333     corrector,
#     334     cache_matrix,
#     335     assemble_termwise,
#     336     pc_form,
#     337     future,
#     338     overwrite,
#     339 )
#
# TypeError: steady_advection_diffusion() got an unexpected keyword argument 'supg'

# %%
def exact_solution(
    x: np.ndarray,   
    d: float,
) -> np.ndarray:    
    return np.cos(np.pi * x) + sp.erf(x/np.sqrt(2 * d)) / sp.erf(1/np.sqrt(2 * d))


x = np.linspace(*Lx, num=800)

lines = [(x, exact_solution(x, nu))]
legend_labels = ['exact']
for supg in supg_opts:
    lines.append(solutions[supg])
    if supg is None:
        supg = 'unstabilized'
    legend_labels.append(supg)

fig, ax = plot_line(lines, legend_labels, 'SUPG', x_lims=x, x_label='$x$', y_label='$u$')
save_figure('u(x)', thumbnail=True)(fig)
# Out:
# ---------------------------------------------------------------------------
# OverloadTypeError                         Traceback (most recent call last)
# Cell In[2], line 18
#      15         supg = 'unstabilized'
#      16     legend_labels.append(supg)
# ---> 18 fig, ax = plot_line(lines, legend_labels, 'SUPG', x_lims=x, x_label='$x$', y_label='$u$')
#      19 save_figure('u(x)', thumbnail=True)(fig)
#
# File ~/Desktop/LUCiFEx/lucifex/plt/utils.py:108, in _optional_fig_and_or_ax.<locals>._inner(*args, **kwargs)
#     106     plot_func(ax, *_args, **kwargs)
#     107 elif fig_ax_arg == 'fig_ax':
# --> 108     plot_func(fig, ax, *_args, **kwargs)
#     109 else:
#     110     raise ValueError
#
# File ~/Desktop/LUCiFEx/lucifex/plt/line.py:69, in plot_line(fig, ax, f, legend_labels, legend_title, cyc, flip, ax_cbar, cax, **kwargs)
#      67             _plot_line(fi, ax, cyc=cyc, flip=flip, **_kwargs)
#      68         else:
# ---> 69             _plot_line(fi, ax, cyc=Ellipsis, flip=flip, **_kwargs)
#      71 if legend_labels is not None and not isinstance(legend_labels, tuple):
#      72     create_kws_filterer(set_legend)(ax, legend_labels, legend_title, **kwargs)
#
# File ~/miniconda3/envs/lucifex/lib/python3.10/functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/Desktop/LUCiFEx/lucifex/plt/line.py:77, in _plot_line(f, *_, **__)
#      75 @singledispatch
#      76 def _plot_line(f, *_, **__):
# ---> 77     raise OverloadTypeError(f)
#
# OverloadTypeError: Unexpected argument type <class 'collections.defaultdict'>.
