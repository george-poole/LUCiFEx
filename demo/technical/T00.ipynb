# %%
from dolfinx.fem import FunctionSpace

from ufl.core.expr import Expr
from lucifex.mesh import rectangle_mesh, mesh_boundary
from lucifex.fem import SpatialFunction as Function
from lucifex.utils import integral
from lucifex.solver import integration


Lx = 2.0
Ly = 1.0
mesh = rectangle_mesh(Lx, Ly, 20, 10)
boundary = mesh_boundary(
    mesh, 
    {
        "left": lambda x: x[0],
        "right": lambda x: x[0] - Lx,
        "lower": lambda x: x[1],
        "upper": lambda x: x[1] - Ly,
    },
)


@integral
def multiply(a, b) -> Expr:
    return a * b

fs = FunctionSpace(mesh, ('P', 1))
u = Function(fs, lambda x: x[0], name='u')
w = Function(fs, lambda x: x[1], name='w')


uw_dx = multiply('ds', lambda x: x[1] - Ly, lambda x: x[1])(u, w)

uw_dx
# Out:
# INFO:root:running build_ext
# INFO:root:building 'libffcx_forms_32100dc283e1ce3191fe38cdf6f0e8be5c66c069' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/George/miniconda3/envs/lucifex/include -fPIC -O2 -isystem /Users/George/miniconda3/envs/lucifex/include -I/Users/George/miniconda3/envs/lucifex/lib/python3.10/site-packages/ffcx/codegeneration -I/Users/George/miniconda3/envs/lucifex/include/python3.10 -c libffcx_forms_32100dc283e1ce3191fe38cdf6f0e8be5c66c069.c -o ./libffcx_forms_32100dc283e1ce3191fe38cdf6f0e8be5c66c069.o -O2 -g0
# INFO:root:clang -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/George/miniconda3/envs/lucifex/lib -L/Users/George/miniconda3/envs/lucifex/lib -Wl,-rpath,/Users/George/miniconda3/envs/lucifex/lib -L/Users/George/miniconda3/envs/lucifex/lib ./libffcx_forms_32100dc283e1ce3191fe38cdf6f0e8be5c66c069.o -o ./libffcx_forms_32100dc283e1ce3191fe38cdf6f0e8be5c66c069.cpython-310-darwin.so
# (2.0, 1.00105109387035e-17)

# %%
uw_dx
# Out:
# 2.0
