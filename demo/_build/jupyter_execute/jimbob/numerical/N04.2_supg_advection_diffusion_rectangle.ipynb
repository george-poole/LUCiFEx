# %% [markdown]
# ## Example: a rotating pulse on a rectangle
#
# c.f. Donea & Huerta, *Finite Element Methods for Flow Problems* $\S 5.6.1$
#
# $$
# \mathbb{S}=
# \begin{cases}
# \Omega = [0, 1] \times [0, 1] \\
# u_0(x) = 0 \\
# u_{\text{D}}=0 \\
# \textbf{a} = \begin{pmatrix}
# -y \\
# x
# \end{pmatrix} \\
# \mathsf{D}=D\mathsf{I} \\
# R = 0 \\
# J(x,y,t) = e^{-t^{10}}\cos(\pi/2\sqrt{x^2+y^2})\text{H}(1-\sqrt{x^2+y^2})\\
# \end{cases}
# $$
