# %% [markdown]
# # Rotating cone on a rectangle
#
# Donea, J. & Huerta, A. (2003). *Finite Element Methods for Flow Problems*. $\S 3.11.3$
#
# $$
# \mathbb{S}=
# \begin{cases}
# \Omega = [-1/2, 1/2] \times [-1/2, 1/2] \\
# u_0(x,y) = \tfrac{1}{4}(1+\cos(\pi(x-x_0)))(1+\cos(\pi(y-y_0)))~\text{if}~(x-x_0)^2+(y-y_0)^2\leq1\\
# u_0(x,y) = 0~\text{if}~(x-x_0)^2+(y-y_0)^2>1\\
# u_{\text{I}}=0 \\
# \textbf{a} = \begin{pmatrix}
# -y \\
# x
# \end{pmatrix}
# \end{cases}
# $$

# %%
import numpy as np

from lucifex.mesh import interval_mesh
from lucifex.fem import Constant
from lucifex.fdm import (CN, BE, FE, 
    FiniteDifference, FunctionSeries, ConstantSeries,
    cfl_timestep)
from lucifex.solver import ibvp , BoundaryConditions, InitialBoundaryValueProblem
from lucifex.sim import run, Simulation
from lucifex.viz import plot_line
from lucifex.io import write
from lucifex.pde.advection import advection, advection_dg


def create_solver():
    ...
