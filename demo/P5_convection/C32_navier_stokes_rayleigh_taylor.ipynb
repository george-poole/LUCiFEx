# %% [markdown]
# # Rayleigh-Taylor instability of a Navier-Stokes fluid in a rectangle
#
# $$
# \mathbb{S}_{\textbf{u},p,c}
# \begin{cases}
# \Omega = [0, \mathcal{A}X] \times [0, X] & \text{aspect ratio } \mathcal{A}=\mathcal{O}(1) \\
# \textbf{e}_g=-\textbf{e}_y & \text{vertically downward gravity} \\
# c_0(x, y)=\text{H}(y-\tfrac{1}{2}X)+\mathcal{N}(x,y) & \text{perturbed initial stratification} \\
# \textbf{u}_0 = \textbf{0} \\
# p_0 = 0 \\
# c_{\text{N}}\vert_{\partial\Omega}=0 & \text{no-flux on entire boundary} \\
# \textbf{u}_{\text{E}}\vert_{\partial\Omega}=\textbf{0} & \text{no-flow on entire boundary} \\
# \rho(c) = c & \text{linear density} \\
# \mu=1 & \text {constant viscosity}
# \end{cases}
# $$

# %%
from lucifex.sim import run
from lucifex.utils.array_utils import as_index
from lucifex.plt import plot_colormap, create_animation, save_figure, display_animation
from py.C32_navier_stokes_rayleigh_taylor import navier_stokes_rayleigh_taylor_rectangle

Ra = 1e5
simulation = navier_stokes_rayleigh_taylor_rectangle(
    aspect=2.0,    
    Nx=64,
    Ny=64,
    Ra=Ra,
    dt_max=0.01, 
)

n_stop = 400
dt_init = 1e-6
n_init = 10
run(simulation, n_stop=n_stop, dt_init=dt_init, n_init=n_init)

c = simulation['c']
mesh = c.mesh
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 from lucifex.utils.array_utils import as_index
#       3 from lucifex.plt import plot_colormap, create_animation, save_figure, display_animation
# ----> 4 from py.C32_navier_stokes_rayleigh_taylor import navier_stokes_rayleigh_taylor_rectangle
#       6 Ra = 1e5
#       7 simulation = navier_stokes_rayleigh_taylor_rectangle(
#       8     aspect=2.0,
#       9     Nx=64,
#    (...)
#      12     dt_max=0.01,
#      13 )
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C32_navier_stokes_rayleigh_taylor.py:18
#      15 from lucifex.pde.constitutive import newtonian_stress
#      16 from lucifex.pde.advection_diffusion import advection_diffusion
# ---> 18 from .C31_navier_stokes_thermosolutal import NAVIER_STOKES_CONVECTION_SCALINGS
#      21 @configure_simulation(
#      22     store_delta=1,
#      23     write_delta=None,
#    (...)
#      49     D_diff_c: FiniteDifference = CN,
#      50 ):
#      51     """
#      52     `∂c/∂t + 𝐮·∇c = Di∇²c` \\
#      53     `∇·𝐮 = 0` \\
#      54     `∂𝐮/∂t + 𝐮·∇𝐮 = Vi(-∇p + ∇²𝐮) - Bu c 𝐞ʸ`
#      55     """
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C31_navier_stokes_thermosolutal.py:18
#      16 from lucifex.pde.advection_diffusion import advection_diffusion
#      17 from lucifex.pde.constitutive import newtonian_stress
# ---> 18 from lucifex.pde.scaling import ScalingOptionss
#      21 NAVIER_STOKES_CONVECTION_SCALINGS = ScalingOptionss(
#      22     ('Ad', 'Di', 'Vi', 'Bu', 'X'),
#      23     lambda Ra, Pr: {
#    (...)
#      26     }
#      27 )
#      28 """
#      29 Choice of length scale `ℒ`, velocity scale `𝒰`
#      30 and time scale `𝒯` in the non-dimensionalization.
#    (...)
#      38 `𝒰` = diffusive speed
#      39 """
#
# ImportError: cannot import name 'ScalingOptionss' from 'lucifex.pde.scaling' (/Users/George/Desktop/LUCiFEx/lucifex/pde/scaling.py)

# %%
time_slice = slice(0, None, 2)
titles = [f'$c(t={t:.3f})$' for t in c.time_series[time_slice]]

anim = create_animation(
    plot_colormap,
    colorbar=False,
)(c.series[time_slice], title=titles)
anim_path = save_figure(f'{c.name}(x,y,t)', return_path=True)(anim)

display_animation(anim_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 time_slice = slice(0, None, 2)
# ----> 2 titles = [f'$c(t={t:.3f})$' for t in c.time_series[time_slice]]
#       4 anim = create_animation(
#       5     plot_colormap,
#       6     colorbar=False,
#       7 )(c.series[time_slice], title=titles)
#       8 anim_path = save_figure(f'{c.name}(x,y,t)', return_path=True)(anim)
#
# NameError: name 'c' is not defined

# %%
time_indices = as_index(c.time_series, (0, 0.5, -1), fraction=True)
for i in time_indices:
    t = c.time_series[i]
    fig, ax = plot_colormap(c.series[i], title=f'$c(t={t:.2f})$')
    save_figure(f'c(x,y,t={c.time_series[i]:.3f})', thumbnail=(i == -1))(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 time_indices = as_index(c.time_series, (0, 0.5, -1), fraction=True)
#       2 for i in time_indices:
#       3     t = c.time_series[i]
#
# NameError: name 'c' is not defined
