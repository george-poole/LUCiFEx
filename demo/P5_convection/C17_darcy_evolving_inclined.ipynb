# %% [markdown]
# # Evolving convection of a Darcy fluid in an inclined porous rectangle
#
# $$
# \mathbb{S}
# \begin{cases}
# \Omega = [0, \mathcal{A}X] \times [0, X] & \text{aspect ratio } \mathcal{A}=\mathcal{O}(1)\\
# \textbf{e}_g=-\sin\beta\textbf{e}_x-\cos\beta\textbf{e}_y & \text{gravity acting at an angle $\beta$ to the vertical coordinate} \\
# c_0(x,y)=\lim_{\epsilon\to0}\frac{1}{2}\left(1+\text{erf}\left(\frac{y-Ra}{\epsilon Ra}\right)\right)+\mathcal{N}(x,y) & \text{perturbed diffusive base state} \\
# c_{\text{D}}(x,y=Ra)=1 & \text{prescribed concentration on upper and lower boundaries} \\
# c_{\text{N}}(x,y=0)=0 & \text{no-flux on lower, left and right boundaries}\\
# c_{\text{N}}(x=0,y)=0 \\
# c_{\text{N}}(x=\mathcal{A}X,y)=0 \\
# \psi_{\text{D}}\vert_{\partial\Omega}=0 & \text{no-penetration on entire boundary} \\
# \phi = 1 & \text{constitutive relations} \\
# \mathsf{D} = \mathsf{I} \\
# \mathsf{K} = \mathsf{I}\\
# \mu = 1 \\
# \rho(c) = c \\
# \end{cases}
# $$

# %%
import numpy as np
from matplotlib.patches import FancyArrowPatch
from lucifex.fdm import AB2, CN
from lucifex.sim import run
from lucifex.utils.array_utils import as_index
from lucifex.plt import plot_colormap, save_figure, create_animation, display_animation
from py.C14_darcy_evolving import darcy_convection_evolving_rectangle

beta = 20.0
simulation = darcy_convection_evolving_rectangle(
    aspect=2.0,
    Nx=64,
    Ny=64,
    cell='quadrilateral', 
    scaling='advective',
    Ra=300.0, 
    beta=beta,
    c_ampl=1e-4, 
    c_freq=(14, 14), 
    c_seed=(456, 987), 
    D_adv=AB2,
    D_diff=CN,
)

n_stop = 200
dt_init = 1e-6
n_init = 5
run(simulation, n_stop=n_stop, dt_init=dt_init, n_init=n_init)

c = simulation['c']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 from lucifex.utils.array_utils import as_index
#       6 from lucifex.plt import plot_colormap, save_figure, create_animation, display_animation
# ----> 7 from py.C14_darcy_evolving import darcy_convection_evolving_rectangle
#       9 beta = 20.0
#      10 simulation = darcy_convection_evolving_rectangle(
#      11     aspect=2.0,
#      12     Nx=64,
#    (...)
#      22     D_diff=CN,
#      23 )
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C14_darcy_evolving.py:14
#      11 from lucifex.utils.fenicsx_utils import CellType
#      12 from lucifex.pde.constitutive import permeability_cross_bedded
# ---> 14 from .C10_darcy_convection_generic import darcy_convection_generic, DARCY_CONVECTION_SCALINGS
#      17 @configure_simulation(
#      18     store_delta=1,
#      19     write_delta=None,
#    (...)
#      52 ) -> Simulation:
#      53     # space
#      54     scaling_map = DARCY_CONVECTION_SCALINGS[scaling](Ra)
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C10_darcy_convection_generic.py:27
#      25 from lucifex.pde.advection_diffusion import advection_diffusion, flux
#      26 from lucifex.pde.darcy import darcy_streamfunction
# ---> 27 from lucifex.pde.scaling import ScalingOptionss
#      30 DARCY_CONVECTION_SCALINGS = ScalingOptionss(
#      31     ('Ad', 'Di', 'Bu', 'X'),
#      32     lambda Ra: {
#    (...)
#      36     }
#      37 )
#      38 """
#      39 Choice of length scale `ℒ`, velocity scale `𝒰`
#      40 and time scale `𝒯` in the non-dimensionalization.
#    (...)
#      52 `𝒰` = advective speed
#      53 """
#
# ImportError: cannot import name 'ScalingOptionss' from 'lucifex.pde.scaling' (/Users/George/Desktop/LUCiFEx/lucifex/pde/scaling.py)

# %%
time_slice = slice(0, None, 2)
titles = [f'${c.name}(t={t:.3f})$' for t in c.time_series[time_slice]]

anim = create_animation(
    plot_colormap,
    colorbar=False,
)(c.series[time_slice], title=titles)
anim_path = save_figure(f'{c.name}(t)', return_path=True)(anim)

display_animation(anim_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 time_slice = slice(0, None, 2)
# ----> 2 titles = [f'${c.name}(t={t:.3f})$' for t in c.time_series[time_slice]]
#       4 anim = create_animation(
#       5     plot_colormap,
#       6     colorbar=False,
#       7 )(c.series[time_slice], title=titles)
#       8 anim_path = save_figure(f'{c.name}(t)', return_path=True)(anim)
#
# NameError: name 'c' is not defined

# %%
Lx, Ly = 2.0, 1.0
arrow_len = 0.2
arrow_start = 0.5 * np.array((Lx, Ly))
arrow_end = arrow_start - arrow_len * np.array((np.sin(np.radians(beta)), np.cos(np.radians(beta))))

time_indices = as_index(c.time_series, (0, 0.5, -1), fraction=True)
for i in time_indices:
    fig, ax = plot_colormap(c.series[i], title=f'$c(t={c.time_series[i]:.2f})$')
    arrow = FancyArrowPatch(
        arrow_start,
        arrow_end,
        arrowstyle='-|>',
        mutation_scale=15,
        color='cyan',
        linewidth=2.0,
    )
    ax.add_patch(arrow)
    save_figure(f'{c.name}(t={c.time_series[i]:.2f})', thumbnail=(i == -1))(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 arrow_len = 0.2
#       3 arrow_start = 0.5 * np.array((Lx, Ly))
# ----> 4 arrow_end = arrow_start - arrow_len * np.array((np.sin(np.radians(beta)), np.cos(np.radians(beta))))
#       6 time_indices = as_index(c.time_series, (0, 0.5, -1), fraction=True)
#       7 for i in time_indices:
#
# NameError: name 'beta' is not defined
