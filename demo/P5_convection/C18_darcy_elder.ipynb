# %% [markdown]
# # Elder convection of a Darcy fluid in a porous rectangle

# %% [markdown]
# $$
# \mathbb{S}_{\psi,c}
# \begin{cases}
# \Omega = [0, \mathcal{A}X] \times [0, X] & \text{aspect ratio } \mathcal{A}=\mathcal{O}(1)\\
# c_0(x,y)=\mathcal{N}(x,y) & \text{perturbed initial concentration} \\
# c_{\text{D}}(x,y=1)=\begin{cases}
# 1 & x<\frac{\mathcal{A}X}{2} \\
# 0 & \text{otherwise}
# \end{cases}=0 & \text{step concentration upper boundary} \\
# c_{\text{D}}(x,y=0)=0 & \text{zero concentration lower boundary} \\
# c_{\text{N}}(x=0,y)=0 & \text{no-flux on left boundary}\\
# c_{\text{N}}(x=L_x,y)=0 & \text{no-flux on right boundary}\\
# \psi_{\text{D}}\vert_{\partial\Omega}=0 & \text{no-penetration on entire boundary} \\
# \phi = 1 & \text{constant porosity} \\
# \mathsf{D} = \mathsf{I} & \text{constant isotropic dispersion} \\
# \mathsf{K} = \mathsf{I} & \text{constant isotropic permeability} \\
# \mu = 1 & \text{constant viscosity} \\
# \rho(c) = c & \text{linear density} \\
# \textbf{e}_g=-\textbf{e}_y & \text{vertically downward gravity}\\
# \end{cases}
# $$

# %%
from lucifex.fdm import AB2, CN
from lucifex.sim import run
from lucifex.utils.array_utils import as_index
from lucifex.plt import plot_colormap, save_figure, create_animation, display_animation
from py.C18_darcy_elder import darcy_convection_elder_rectangle

simulation = darcy_convection_elder_rectangle(
    aspect=2.0,
    Nx=64,
    Ny=64,
    cell='quadrilateral', 
    scaling='advective',
    Ra=400.0, 
    c_ampl=1e-4, 
    c_freq=(12, 12), 
    c_seed=(789, 987), 
    D_adv=AB2 @ CN,
    D_diff=CN,
)

n_stop = 200
dt_init = 1e-6
n_init = 5
run(simulation, n_stop=n_stop, dt_init=dt_init, n_init=n_init)

c = simulation['c']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 from lucifex.utils.array_utils import as_index
#       4 from lucifex.plt import plot_colormap, save_figure, create_animation, display_animation
# ----> 5 from py.C18_darcy_elder import darcy_convection_elder_rectangle
#       7 simulation = darcy_convection_elder_rectangle(
#       8     aspect=2.0,
#       9     Nx=64,
#    (...)
#      18     D_diff=CN,
#      19 )
#      21 n_stop = 200
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C18_darcy_elder.py:8
#       5 from lucifex.sim import configure_simulation
#       6 from lucifex.utils.fenicsx_utils import CellType
# ----> 8 from .C10_darcy_convection_generic import darcy_convection_generic, DARCY_CONVECTION_SCALINGS
#      11 @configure_simulation(
#      12     store_delta=1,
#      13     write_delta=None,
#    (...)
#      34 ):
#      35     # space
#      36     scaling_map = DARCY_CONVECTION_SCALINGS[scaling](Ra)
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C10_darcy_convection_generic.py:27
#      25 from lucifex.pde.advection_diffusion import advection_diffusion, flux
#      26 from lucifex.pde.darcy import darcy_streamfunction
# ---> 27 from lucifex.pde.scaling import ScalingOptionss
#      30 DARCY_CONVECTION_SCALINGS = ScalingOptionss(
#      31     ('Ad', 'Di', 'Bu', 'X'),
#      32     lambda Ra: {
#    (...)
#      36     }
#      37 )
#      38 """
#      39 Choice of length scale `ℒ`, velocity scale `𝒰`
#      40 and time scale `𝒯` in the non-dimensionalization.
#    (...)
#      52 `𝒰` = advective speed
#      53 """
#
# ImportError: cannot import name 'ScalingOptionss' from 'lucifex.pde.scaling' (/Users/George/Desktop/LUCiFEx/lucifex/pde/scaling.py)

# %%
time_slice = slice(0, None, 2)
titles = [f'$c(t={t:.3f})$' for t in c.time_series[time_slice]]

anim = create_animation(
    plot_colormap,
    colorbar=(0, 1),
)(c.series[time_slice], title=titles)
anim_path = save_figure('c(t)', get_path=True)(anim)

display_animation(anim_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 time_slice = slice(0, None, 2)
# ----> 2 titles = [f'$c(t={t:.3f})$' for t in c.time_series[time_slice]]
#       4 anim = create_animation(
#       5     plot_colormap,
#       6     colorbar=(0, 1),
#       7 )(c.series[time_slice], title=titles)
#       8 anim_path = save_figure('c(t)', get_path=True)(anim)
#
# NameError: name 'c' is not defined

# %%
time_indices = as_index(c.time_series, (0, 0.25, 0.5, -1), fraction=True)
for i in time_indices:
    fig, ax = plot_colormap(c.series[i], title=f'$c(t={c.time_series[i]:.2f})$')
    save_figure(f'c(t={c.time_series[i]:.2f})', thumbnail=(i == -1))(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 time_indices = as_index(c.time_series, (0, 0.25, 0.5, -1), fraction=True)
#       2 for i in time_indices:
#       3     fig, ax = plot_colormap(c.series[i], title=f'$c(t={c.time_series[i]:.2f})$')
#
# NameError: name 'c' is not defined
