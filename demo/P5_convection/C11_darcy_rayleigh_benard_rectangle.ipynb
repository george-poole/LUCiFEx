# %% [markdown]
# # Rayleigh-Bénard convection of a Darcy fluid in a porous rectangle
#
# $$
# \mathbb{S}_{\psi,c}
# \begin{cases}
# \Omega = [0, \mathcal{A}X] \times [0, X] & \text{aspect ratio } \mathcal{A}=\mathcal{O}(1)\\
# c_0(x,y)=1-y+\mathcal{N}(x,y) & \text{perturbed initial linear concencentration} \\
# c_{\text{D}}(x,y=0)=1 & \text{hot lower boundary} \\
# c_{\text{D}}(x,y=1)=0 & \text{cold upper boundary} \\
# c_{\text{N}}(x=0,y)=0 & \text{no-flux on left boundary}\\
# c_{\text{N}}(x=L_x,y)=0 & \text{no-flux on right boundary}\\
# \psi_{\text{D}}\vert_{\partial\Omega}=0 & \text{no-penetration on entire boundary} \\
# \phi = 1 & \text{constant porosity} \\
# \mathsf{D} = \mathsf{I} & \text{constant isotropic dispersion}\\
# \mathsf{K} = \mathsf{I} & \text{constant isotropic permeability}\\
# \mu = 1 & \text{constant viscosity} \\
# \rho(c) = -c & \text{linear density} \\
# \textbf{e}_g=-\textbf{e}_y & \text{vertically downward gravity} \\
# \end{cases}
# $$

# %%
import numpy as np
from lucifex.fdm import AB2, CN
from lucifex.sim import run
from lucifex.mesh import as_grid_mesh
from lucifex.fem import cross_section_grid
from lucifex.utils.array_utils import as_index
from lucifex.plt import plot_colormap, plot_line, create_animation, save_figure, display_animation
from py.C11_darcy_rayleigh_benard import darcy_rayleigh_benard_rectangle

simulation = darcy_rayleigh_benard_rectangle(
    aspect=2.0,  
    Nx=64,
    Ny=64,
    cell='quadrilateral', 
    scaling='advective',
    Ra=500.0, 
    c_ampl=1e-3, 
    c_freq=(12, 8), 
    c_seed=(123, 456), 
    D_adv=AB2,
    D_diff=CN,
    diagnostic=True,
)

n_stop = 200
dt_init = 1e-6
n_init = 5
run(simulation, n_stop=n_stop, dt_init=dt_init, n_init=n_init)

c = simulation['c']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6 from lucifex.utils.array_utils import as_index
#       7 from lucifex.plt import plot_colormap, plot_line, create_animation, save_figure, display_animation
# ----> 8 from py.C11_darcy_rayleigh_benard import darcy_rayleigh_benard_rectangle
#      10 simulation = darcy_rayleigh_benard_rectangle(
#      11     aspect=2.0,
#      12     Nx=64,
#    (...)
#      22     diagnostic=True,
#      23 )
#      25 n_stop = 200
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C11_darcy_rayleigh_benard.py:11
#       8 from lucifex.sim import configure_simulation
#       9 from lucifex.utils.fenicsx_utils import CellType
# ---> 11 from .C10_darcy_convection_generic import darcy_convection_generic, DARCY_CONVECTION_SCALINGS
#      14 @configure_simulation(
#      15     store_delta=1,
#      16     write_delta=None,
#    (...)
#      41     diagnostic: bool = False,
#      42 ):
#      43     """
#      44     `Ω = [0, A·X] × [0, X]` \\
#      45     `∂c/∂t + 𝐮·∇c = Di ∇²c` \\
#    (...)
#      49     `scaling` determines `Di, Bu, Xl` from `Ra`.
#      50     """
#
# File ~/Desktop/LUCiFEx/demo/P5_convection/py/C10_darcy_convection_generic.py:27
#      25 from lucifex.pde.advection_diffusion import advection_diffusion, flux
#      26 from lucifex.pde.darcy import darcy_streamfunction
# ---> 27 from lucifex.pde.scaling import ScalingOptionss
#      30 DARCY_CONVECTION_SCALINGS = ScalingOptionss(
#      31     ('Ad', 'Di', 'Bu', 'X'),
#      32     lambda Ra: {
#    (...)
#      36     }
#      37 )
#      38 """
#      39 Choice of length scale `ℒ`, velocity scale `𝒰`
#      40 and time scale `𝒯` in the non-dimensionalization.
#    (...)
#      52 `𝒰` = advective speed
#      53 """
#
# ImportError: cannot import name 'ScalingOptionss' from 'lucifex.pde.scaling' (/Users/George/Desktop/LUCiFEx/lucifex/pde/scaling.py)

# %%
time_slice = slice(0, None, 2)
titles = [f'$c(t={t:.3f})$' for t in c.time_series[time_slice]]

anim = create_animation(
    plot_colormap,
    colorbar=False,
)(c.series[time_slice], title=titles)
anim_path = save_figure(f'{c.name}(x,y,t)', return_path=True)(anim)

display_animation(anim_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 time_slice = slice(0, None, 2)
# ----> 2 titles = [f'$c(t={t:.3f})$' for t in c.time_series[time_slice]]
#       4 anim = create_animation(
#       5     plot_colormap,
#       6     colorbar=False,
#       7 )(c.series[time_slice], title=titles)
#       8 anim_path = save_figure(f'{c.name}(x,y,t)', return_path=True)(anim)
#
# NameError: name 'c' is not defined

# %%
time_indices = as_index(c.time_series, (0, 0.5, -1), fraction=True)
for i in time_indices:
    fig, ax = plot_colormap(c.series[i], title=f'$c(t={c.time_series[i]:.3f})$')
    thumbnails = './thumbnails' if i == -1 else None
    save_figure(f'c(x,y,t={c.time_series[i]:.3f})', thumbnails=thumbnails)(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 time_indices = as_index(c.time_series, (0, 0.5, -1), fraction=True)
#       2 for i in time_indices:
#       3     fig, ax = plot_colormap(c.series[i], title=f'$c(t={c.time_series[i]:.3f})$')
#
# NameError: name 'c' is not defined

# %%
grid_mesh = as_grid_mesh(c.mesh)
x, y = grid_mesh.axes

y_index = 8
y_value = y[y_index]
cx_series = cross_section_grid_series(c.series, 'y', y_value)
cxt = np.array([cx.value for cx in cx_series]).T

title = f'$c(y={y_value:.3f})$'
fig, ax = plot_colormap(
    (x, c.time_series, cxt), 
    aspect='auto',
    x_label='$x$',
    y_label='$t$',
    title=title,
    colorbar=(0, 1),
)
save_figure(title.strip('$'))(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 grid_mesh = as_grid_mesh(c.mesh)
#       2 x, y = grid_mesh.axes
#       4 y_index = 8
#
# NameError: name 'c' is not defined

# %%
uRMS, uMinMax = simulation['uRMS', 'uMinMax']
uMax = uMinMax.sub(1)

fig, ax = plot_line(
    (uRMS.time_series, uRMS.value_series),
    x_label='$t$',
    y_label='$\mathrm{rms}(\\textbf{u})$',
)
save_figure('uRMS(t)')(fig)

fig, ax = plot_line(
    (uMax.time_series, uMax.value_series),
    x_label='$t$',
    y_label='$\max_{\\textbf{x}}|\\textbf{u}|$',
)
save_figure('uMax(t)')(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 uRMS, uMinMax = simulation['uRMS', 'uMinMax']
#       2 uMax = uMinMax.sub(1)
#       4 fig, ax = plot_line(
#       5     (uRMS.time_series, uRMS.value_series),
#       6     x_label='$t$',
#       7     y_label='$\mathrm{rms}(\\textbf{u})$',
#       8 )
#
# NameError: name 'simulation' is not defined

# %%
dt, dtCFL = simulation['dt', 'dtCFL']

fig, ax = plot_line(
    [(dt.time_series, dt.value_series), (dtCFL.time_series, dtCFL.value_series)],
    x_label='$t$',
    legend_labels=['$\Delta t$', '$\Delta t_{\mathbf{u}}$'],
)
ax.set_yscale('log')
save_figure('dt(t)')(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dt, dtCFL = simulation['dt', 'dtCFL']
#       3 fig, ax = plot_line(
#       4     [(dt.time_series, dt.value_series), (dtCFL.time_series, dtCFL.value_series)],
#       5     x_label='$t$',
#       6     legend_labels=['$\Delta t$', '$\Delta t_{\mathbf{u}}$'],
#       7 )
#       8 ax.set_yscale('log')
#
# NameError: name 'simulation' is not defined

# %%
cMinMax = simulation['cMinMax']
cMin, cMax = cMinMax.split()

fig, ax = plot_line(
    (cMax.time_series, cMax.value_series),
    x_label='$t$',
    y_label='$\max_{\\textbf{x}}(c)$',
)
save_figure('cMax(t)')(fig)

fig, ax = plot_line(
    (cMin.time_series, cMin.value_series),
    x_label='$t$',
    y_label='$\min_{\\textbf{x}}(c)$',
)
save_figure('cMin(t)')(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cMinMax = simulation['cMinMax']
#       2 cMin, cMax = cMinMax.split()
#       4 fig, ax = plot_line(
#       5     (cMax.time_series, cMax.value_series),
#       6     x_label='$t$',
#       7     y_label='$\max_{\\textbf{x}}(c)$',
#       8 )
#
# NameError: name 'simulation' is not defined
