# %% [markdown]
# # Darcy fingering in a porous rectangle with Dirichlet boundary conditions

# %% [markdown]
# $$
# \mathbb{S}
# \begin{cases}
# \Omega = [-L_x/2, L_x/2] \times [0, 1] \\
# \phi = 1 & \text{constitutive relations} \\
# \mathsf{D} = \mathsf{I} \\
# \mathsf{K} = \mathsf{I}\\
# \mu(c) = \exp(-\Lambda c) \\
# c_0(x,y)=\lim_{\epsilon\to0}\frac{1}{2}\left(1+\text{erf}\left(-\frac{x}{\epsilon L_x}\right)\right)+\mathcal{N}(x,y) & \text{smoothed step plus noise}\\
# c_{\text{D}}(x=-\tfrac{1}{2}L_x,y)=1 \\
# c_{\text{D}}(x=\tfrac{1}{2}L_x,y)=0 \\
# c_{\text{N}}(x,y=0)=0 & \text{no-flux on upper and lower boundaries} \\
# c_{\text{N}}(x,y=L_y)=0 \\
# \psi_{\text{D}}\vert_{\partial\Omega} = 0 & \text{no-penetration on entire boundary}
# \end{cases}
# $$

# %%
from lucifex.fdm import AB2, CN
from lucifex.sim import run
from lucifex.utils import as_indices
from lucifex.viz import plot_colormap, save_figure, create_animation, display_animation
from py.A08_darcy_fingering import darcy_fingering_rectangle


simulation = darcy_fingering_rectangle(
    aspect=2.0,
    Nx=160,
    Ny=80,
    cell='quadrilateral', 
    scaling='advective',
    Pe=200.0,
    Lmbda=5.0, 
    bc_type='dirichlet',
    D_adv=AB2,
    D_diff=CN,
)

n_stop = 200
dt_init = 1e-6
n_init = 5
run(simulation, n_stop=n_stop, dt_init=dt_init, n_init=n_init)

c, psi = simulation['c', 'psi']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 from lucifex.sim import run
#       3 from lucifex.viz import plot_colormap
# ----> 4 from lucifex.io import write, get_ipynb_file_name
#       6 from py.darcy_saffman_taylor import saffman_taylor_rectangle
#       9 simulation = saffman_taylor_rectangle(
#      10     Lx=2.0,
#      11     Ly=1.0,
#    (...)
#      19     D_diff=CN,
#      20 )
#
# ImportError: cannot import name 'get_ipynb_file_name' from 'lucifex.io' (/Users/George/Desktop/LUCiFEx/lucifex/io/__init__.py)

# %%
time_indices = as_indices(c.series, (0, 0.25, 0.5, -1), fraction=True)
for i in time_indices:
    fig, ax = plot_colormap(c.series[i], title=f'$c(t={c.time_series[i]:.2f})$')
    # save_figure(f'{c.name}(t={c.time_series[i]:.2f})')(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c, psi = simulation['c', 'psi']
#       3 i_qrt = int(0.25 * len(c.series))
#       4 i_mid = int(0.5 * len(c.series))
#
# NameError: name 'simulation' is not defined
