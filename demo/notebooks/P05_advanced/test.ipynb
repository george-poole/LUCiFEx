# %%
# import sys

# sys.path.append('./')

import sys

sys.path.append('..')
from c04_convection.py.C01_darcy_convection_generic import *

# %%
darcy_convection_generic
# Out:
# <function c04_convection.py.C01_darcy_convection_generic.darcy_convection_generic(Omega: dolfinx.mesh.Mesh, dOmega: lucifex.mesh.boundary.MeshBoundary, egx: ufl.core.expr.Expr | lucifex.fem.function.Function | lucifex.fem.constant.Constant | float = 0, egy: ufl.core.expr.Expr | lucifex.fem.function.Function | lucifex.fem.constant.Constant | float = -1, c_ics=None, c_bcs: lucifex.solver.bcs.BoundaryConditions | ellipsis | None = Ellipsis, psi_bcs: lucifex.solver.bcs.BoundaryConditions | ellipsis | None = Ellipsis, porosity: Union[Callable[[numpy.ndarray], numpy.ndarray], float] = 1, permeability: Callable[[lucifex.fem.function.Function], ufl.core.expr.Expr] = <function <lambda> at 0x154d60280>, dispersion: Union[Callable[[lucifex.fem.function.Function, lucifex.fdm.series.FunctionSeries], lucifex.fdm.series.Series], Callable[[lucifex.fem.function.Function], lucifex.fem.function.Function]] = <function <lambda> at 0x154d603a0>, density: Callable[[lucifex.fdm.series.FunctionSeries], lucif
# ...
