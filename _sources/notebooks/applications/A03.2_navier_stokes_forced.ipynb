# %% [markdown]
# # Flow of a Navier-Stokes fluid with vertical forcing
#
# $$
# \mathbb{S}
# \begin{cases}
# \Omega = [0, L_x] \times [0, L_y] \\
# f_x = 0 \\
# f_y(x,y) = 5y\sin(6\pi x/L_x) \\
# \psi_{\text{D}}\vert_{\partial\Omega} = 0 & \text{equivalent to no-penetration } (\textbf{n}\cdot\textbf{u})\vert_{\partial\Omega}=0\\
# \omega_{\text{D}}\vert_{\partial\Omega} = 0
# \end{cases}
# $$

# %%
import numpy as np

from lucifex.mesh import rectangle_mesh, mesh_boundary
from lucifex.fdm import (
    FunctionSeries, ConstantSeries, FiniteDifference, FiniteDifferenceArgwise,
    AB1, CN, finite_difference_order, cfl_timestep,
)
from lucifex.fem import Function, Constant
from lucifex.solver import bvp, ibvp, interpolation, evaluation, BoundaryConditions
from lucifex.utils import CellType
from lucifex.sim import configure_simulation, run
from lucifex.viz import plot_colormap, plot_contours
from lucifex.io import write
from lucifex.pde.streamfunction import streamfunction_velocity
from lucifex.pde.navier_stokes import vorticity_poisson, vorticity_transport



@configure_simulation(
    store_delta=1,
    write_delta=None,
)
def streamfunction_vorticity_2d(
    Lx: float = 1.0,
    Ly: float = 1.0,
    Nx: int = 100,
    Ny: int = 100,
    cell: str = CellType.QUADRILATERAL,
    dt_max: float = 0.1,
    dt_min: float = 0.0,
    cfl_courant: float = 0.75,
    D_adv: FiniteDifference | FiniteDifferenceArgwise = AB1,
    D_diff: FiniteDifference = CN,
):
    order = finite_difference_order(D_adv, D_diff)
    mesh = rectangle_mesh(Lx, Ly, Nx, Ny, cell)
    boundary = mesh_boundary(
        mesh, 
        {
            "left": lambda x: x[0],
            "right": lambda x: x[0] - Lx,
            "lower": lambda x: x[1],
            "upper": lambda x: x[1] - Ly,
        },
    )

    t = ConstantSeries(mesh, 't', ics=0.0)
    dt = ConstantSeries(mesh, 'dt')
    psi = FunctionSeries((mesh, 'P', 2), 'psi', order)
    omega = FunctionSeries((mesh, 'P', 1), 'omega', order, ics=0.0)
    u = FunctionSeries((mesh, 'P', 1, 2), 'u', order)

    rho = Constant(mesh, 1.0, name='rho')
    mu = Constant(mesh, 1.0, name='mu')

    fx = None
    fy = Function(
        (mesh, 'P', 1), 
        lambda x: 5 * x[1] * np.sin(6 * np.pi * x[0] / Lx),
        name='fy',
    )

    psi_bcs = BoundaryConditions(("dirichlet", boundary.union, 0.0))
    psi_solver = bvp(vorticity_poisson, psi_bcs)(psi, omega[0])

    u_solver = interpolation(u, streamfunction_velocity)(psi[0])

    dt_solver = evaluation(dt, cfl_timestep)(
        u[0], 'hmin', cfl_courant, dt_max, dt_min,
    )

    omega_bcs = BoundaryConditions(("dirichlet", boundary.union, 0.0))
    omega_solver = ibvp(vorticity_transport, bcs=omega_bcs)(
        omega, dt[0], u, rho, mu, D_adv, D_diff, fx, fy)
    
    solvers = [psi_solver, u_solver, dt_solver, omega_solver]
    namespace = [rho, mu, fy]

    return solvers, t, dt, namespace

# %%
simulation = streamfunction_vorticity_2d(
    Lx=1.0,
    Ly=1.0,
    Nx=64,
    Ny=64,
)

n_stop = 100
dt_init = 1e-6
n_init = 5
run(simulation, n_stop=n_stop, dt_init=dt_init, n_init=n_init)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 simulation = streamfunction_vorticity_2d(
#       2     Lx=1.0,
#       3     Ly=1.0,
#       4     Nx=64,
#       5     Ny=64,
#       6 )
#       8 n_stop = 100
#       9 dt_init = 1e-6
#
# File ~/Desktop/LUCiFEx/lucifex/sim/simulation.py:381, in configure_simulation.<locals>._decorator.<locals>._(*args, **kwargs)
#     379 if len(error_params) > 1:
#     380     raise TypeError(f'Unrecognised keyword arguments: {tuple(error_params)}.')
# --> 381 return _(
#     382     petsc=petsc,
#     383     jit=jit,
#     384     ffcx=ffcx,
#     385     store_delta=store_delta,
#     386     write_delta=write_delta,
#     387     dir_base=dir_base,
#     388     dir_params=dir_params,
#     389     dir_prefix=dir_prefix,
#     390     dir_suffix=dir_suffix,
#     391     dir_timestamp=dir_timestamp,
#     392     write_file=write_file,
#     393     parameter_file=parameter_file,
#     394     checkpoint_file=checkpoint_file,
#     395     timing_file=timing_file,
#     396 )(*args, **kwargs)
#
# File ~/Desktop/LUCiFEx/lucifex/sim/simulation.py:350, in configure_simulation.<locals>._decorator.<locals>._.<locals>._inner(*sim_func_args, **sim_func_kwargs)
#     341 classes = (
#     342     BoundaryValueProblem,
#     343     InitialBoundaryValueProblem,
#    (...)
#     347     Interpolation,
#     348 )
#     349 [filter_kwargs(cls.set_defaults)(**kwargs_complete) for cls in classes]
# --> 350 simulation_func_return = simulation_func(*sim_func_args, **sim_func_kwargs)
#     351 [cls.set_defaults() for cls in classes]
#     353 sim_parameters = {
#     354     k: v.default
#     355     for k, v in simulation_func_params.items()
#     356     if v.default is not v.empty
#     357 }
#
# Cell In[1], line 73, in streamfunction_vorticity_2d(Lx, Ly, Nx, Ny, cell, dt_max, dt_min, cfl_courant, D_adv, D_diff)
#      68 dt_solver = evaluation(dt, cfl_timestep)(
#      69     u[0], 'hmin', cfl_courant, dt_max, dt_min,
#      70 )
#      72 omega_bcs = BoundaryConditions(("dirichlet", boundary.union, 0.0))
# ---> 73 omega_solver = ibvp(vorticity_transport, bcs=omega_bcs)(
#      74     omega, dt[0], u, rho, mu, D_adv, D_diff, fx, fy)
#      76 solvers = [psi_solver, u_solver, dt_solver, omega_solver]
#      77 namespace = [rho, mu, fy]
#
# File ~/Desktop/LUCiFEx/lucifex/solver/pde.py:554, in InitialBoundaryValueProblem.from_forms_func.<locals>._create(*args, **kwargs)
#     552     else:
#     553         solution = list(kwargs.values())[0]
# --> 554 forms = forms_func(*args, **kwargs)
#     556 def _init(arg):
#     557     if isinstance(arg, (FiniteDifference, FiniteDifferenceArgwise)):
#
# File ~/Desktop/LUCiFEx/lucifex/pde/navier_stokes.py:238, in vorticity_transport(omega, dt, u, rho, mu, D_adv, D_diff, D_reac, fx, fy)
#     236 if not fy is not _none:
#     237     r += Dx(fy, 0) / rho
# --> 238 return advection_diffusion_reaction(omega, dt, u, d, r, D_adv, D_diff, D_reac)
#
# File ~/Desktop/LUCiFEx/lucifex/pde/advection_diffusion.py:75, in advection_diffusion_reaction(u, dt, a, d, r, j, D_adv, D_diff, D_reac, D_src, D_phi, D_dt, phi, bcs, supg, h)
#      70 dx = Measure('dx', u.function_space.mesh)
#      71 phi = D_phi(phi)
#      72 forms = [
#      73     derivative_form(v/phi, u, dt, D_dt, dx),
#      74     advection_form(v/phi, u, a, D_adv, dx),
# ---> 75     *diffusion_forms(-v/phi, u, d, D_diff, bcs, dx),
#      76     *reaction_forms(-v/phi, u, r, j, D_reac, D_src, dx)
#      77 ]
#      78 if supg is not None:
#      79     terms = [
#      80         derivative_form(1/phi, u, dt, D_dt),
#      81         advection_form(1/phi, u, a, D_adv),
#      82         *diffusion_forms(-1/phi, u, d, D_diff, divergence=True),
#      83         *reaction_forms(-v/phi, u, r, j, D_reac, D_src),
#      84     ]
#
# File ~/Desktop/LUCiFEx/lucifex/pde/cg.py:68, in diffusion_forms(v, u, d, D_diff, bcs, dx, divergence)
#      66         diff = D_diff(expr(d, u), trial=u)
#      67     else:
# ---> 68         diff = D_diff(expr, d, u, trial=u)
#      69     F_diff = -inner(grad(v), diff) * dx
#      71 forms = [F_diff]
#
# TypeError: 'NoneType' object is not callable

# %%
psi = simulation['psi']
time_index = -1

fig, ax = plot_colormap(psi.series[-1], title=f'$\psi(t={psi.time_series[-1]:.3f})$', x_label='$x$', y_label='$y$')
plot_contours(fig, ax, psi.series[time_index], use_cache=True, colors='cyan')
write(fig, f'A14_navier_stokes_streamfunction_vorticity', './figures', close=False, pickle=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 psi = simulation['psi']
#       2 time_index = -1
#       4 fig, ax = plot_colormap(psi.series[-1], title=f'$\psi(t={psi.time_series[-1]:.3f})$', x_label='$x$', y_label='$y$')
#
# NameError: name 'simulation' is not defined
