# %% [markdown]
# # Helmholtz boundary value problem on a rectangle
#
# $$
# \mathbb{S}
# \begin{cases}
# \Omega = [0, L_x] \times [0, L_y] \\
# u_{\text{D}}\vert_{\partial\Omega}=0 \\
# f(x,y)=\sin(2\pi x/L_x)\sin(2\pi y/L_y) \\
# k = 1 \\
# \end{cases}
# $$

# %%
import numpy as np
from dolfinx.fem import FunctionSpace

from lucifex.fem import Function, Constant
from lucifex.mesh import rectangle_mesh, mesh_boundary
from lucifex.solver import BoundaryConditions, bvp
from lucifex.viz import plot_colormap
from lucifex.io import write
from lucifex.pde.eigen import helmholtz


Lx = 2.0
Ly = 1.0
Nx = 32
Ny = 32

mesh = rectangle_mesh(Lx, Ly, Nx, Ny)
boundary = mesh_boundary(
        mesh, 
        {
            "left": lambda x: x[0],
            "right": lambda x: x[0] - Lx,
            "lower": lambda x: x[1],
            "upper": lambda x: x[1] - Ly,
        },
)
bcs = BoundaryConditions(('dirichlet', boundary.union, 0.0))

fs = FunctionSpace(mesh, ('P', 1))

u = Function(fs, name='u')
k = Constant(mesh, 1.0, name='k')
s = Function(
    fs, 
    lambda x: np.sin(2 * np.pi * x[0] / Lx) * np.sin(2 * np.pi * x[1] / Ly), 
    name='s',
)
u_solver = bvp(helmholtz, bcs, solution=u)(fs, k, s)
u_solver.solve()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 38
#      32 k = Constant(mesh, 1.0, name='k')
#      33 s = Function(
#      34     fs,
#      35     lambda x: np.sin(2 * np.pi * x[0] / Lx) * np.sin(2 * np.pi * x[1] / Ly),
#      36     name='s',
#      37 )
# ---> 38 u_solver = bvp(helmholtz, bcs, solution=u)(fs, k, s)
#      39 u_solver.solve()
#
# File ~/Desktop/LUCiFEx/lucifex/solver/pde.py:273, in BoundaryValueProblem.from_forms_func.<locals>._create(*args, **kwargs)
#     269     else:
#     270         solution = list(kwargs.values())[0]
#     271 return cls(
#     272     solution,
# --> 273     forms_func(*args, **kwargs),
#     274     bcs,
#     275     petsc,
#     276     jit,
#     277     ffcx,
#     278     corrector,
#     279     cache_matrix,
#     280     assemble_termwise,
#     281     future,
#     282     overwrite,
#     283 )
#
# File ~/Desktop/LUCiFEx/lucifex/pde/eigen.py:31, in helmholtz(u, k, f, bcs)
#      29 else:
#      30     fs = u.function_space
# ---> 31 dx = Measure('dx', u.function_space.mesh)
#      32 v = TestFunction(fs)
#      33 u_trial = TrialFunction(fs)
#
# AttributeError: 'FunctionSpace' object has no attribute 'function_space'

# %%
fig, ax = plot_colormap(u, title=f'$u$')
write(fig, f'A16_helmholtz_bvp', './figures', close=False, pickle=False)
