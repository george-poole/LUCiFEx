# %% [markdown]
# # Mathieu eigenvalue problem on an interval
#
# $$
# \mathbb{S}
# \begin{cases}
# \Omega = [0, L_x] \\
# \textbf{k}=2\,\textbf{e}_x \\
# u_{\text{D}}\vert_{\partial\Omega}=0 \\
# u^{q=0}_{\text{e}, n}(x)=\sin(\sqrt{\lambda_{\text{e}, n}}x)~,~\lambda^{q=0}_{\text{e}, n}=\frac{n^2\pi^2}{L_x^2}
# \end{cases}
# $$

# %%
import numpy as np
from dolfinx.fem import FunctionSpace

from lucifex.mesh import interval_mesh
from lucifex.fem import Constant
from lucifex.solver import evp, EigenvalueProblem, BoundaryConditions, OptionsSLEPc
from lucifex.viz import plot_line, create_cycler
from lucifex.io import write, get_ipynb_file_name
from lucifex.pde.eigen import mathieu


def create_solver(
    Lx: float,
    Nx: int,
    bcs: BoundaryConditions, 
    q: float,
    k: float,
    nev: int,
) -> EigenvalueProblem:
    mesh = interval_mesh(Lx, Nx)
    q = Constant(mesh, q)
    k = Constant(mesh, (k, ))

    fs = FunctionSpace(mesh, ('P', 1))
    slepc = OptionsSLEPc(
        eps_tol=1e-10,
        eps_target=0.0,
        eps_nev=nev,
        eps_ncv=50,
        eps_max_it=1000,
        eps_which='smallest_real',
    )
    u_solver = evp(mathieu, bcs, slepc)(fs, q, k)
    return u_solver


Lx = 1.0
Nx = 200
bcs = BoundaryConditions(
        ('dirichlet', lambda x: x[0], 0.0),
        ('dirichlet', lambda x: x[0] - Lx, 0.0),
    )
nev = 4
k = 2.0

q_axis = np.linspace(0, 20, num=10)
solvers = [create_solver(Lx, Nx, bcs, q, k, nev) for q in q_axis]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6 from lucifex.solver import evp, EigenvalueProblem, BoundaryConditions, OptionsSLEPc
#       7 from lucifex.viz import plot_line, create_cycler
# ----> 8 from lucifex.io import write, get_ipynb_file_name
#       9 from lucifex.pde.eigen import mathieu
#      12 def create_solver(
#      13     Lx: float,
#      14     Nx: int,
#    (...)
#      18     nev: int,
#      19 ) -> EigenvalueProblem:
#
# ImportError: cannot import name 'get_ipynb_file_name' from 'lucifex.io' (/Users/George/Desktop/LUCiFEx/lucifex/io/__init__.py)

# %%
[s.solve() for s in solvers]
eigenvalues = [s.eigenvalues for s in solvers]
eigenreals = [[np.real(l) for l in lmbdas] for lmbdas in eigenvalues]
eigenreals_q0 = [(n * np.pi/ Lx) ** 2 for n in range(nev)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 [s.solve() for s in solvers]
#       2 eigenvalues = [s.eigenvalues for s in solvers]
#       3 eigenreals = [[np.real(l) for l in lmbdas] for lmbdas in eigenvalues]
#
# NameError: name 'solvers' is not defined

# %%
lines = [
    (q_axis, [eigenreals[q_index][n] for q_index in range(len(q_axis))])
    for n in range(nev)
]
cyc = create_cycler(linestyle=['dashed'], marker=['o'], ms=[4], color=['black'])
slc = slice(1, None)
fig, ax = plot_line(
    lines[slc], 
    cyc=cyc,
    x_label='$q$', 
    y_label='$\lambda(q)$')
ax.set_xlim(q_axis[0], q_axis[-1])
ax.hlines(eigenreals_q0[slc], q_axis[0], q_axis[-1], color='black', lw=0.5, ls='-')
ax.set_yscale('log')
write(fig, get_ipynb_file_name(), './figures', close=False, pickle=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 lines = [
#       2     (q_axis, [eigenreals[q_index][n] for q_index in range(len(q_axis))])
# ----> 3     for n in range(nev)
#       4 ]
#       5 cyc = create_cycler(linestyle=['dashed'], marker=['o'], ms=[4], color=['black'])
#       6 slc = slice(1, None)
#
# NameError: name 'nev' is not defined
