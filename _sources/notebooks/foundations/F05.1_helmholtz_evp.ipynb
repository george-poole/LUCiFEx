# %% [markdown]
# # Helmholtz eigenvalue problem on a rectangle
#
# $$
# \mathbb{S}
# \begin{cases}
# \Omega = [0, L_x] \times [0, L_y] \\
# u_{\text{D}}\vert_{\partial\Omega}=0 \\
# f = 0 \\
# \end{cases}
# $$

# %%
import numpy as np
from dolfinx.fem import FunctionSpace

from lucifex.mesh import rectangle_mesh, mesh_boundary
from lucifex.solver import (
    evp, BoundaryConditions, OptionsSLEPc,
)
from lucifex.viz import plot_colormap
from lucifex.io import write
from lucifex.pde.eigen import helmholtz


Lx = 1.0
Ly = 1.0
Nx = 32
Ny = 32

mesh = rectangle_mesh(Lx, Ly, Nx, Ny)
boundary = mesh_boundary(
        mesh, 
        {
            "left": lambda x: x[0],
            "right": lambda x: x[0] - Lx,
            "lower": lambda x: x[1],
            "upper": lambda x: x[1] - Ly,
        },
)
bcs = BoundaryConditions(('dirichlet', boundary.union, 0.0))
fs = FunctionSpace(mesh, ('P', 1))

nev = 10
slepc = OptionsSLEPc(
    eps_tol=1e-10,
    eps_target=0.0,
    eps_nev=nev,
    eps_ncv=50,
    eps_max_it=1000,
    eps_which='smallest_real',
)
u_solver = evp(helmholtz, bcs, slepc)(fs)
u_solver.solve()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 40
#      31 nev = 10
#      32 slepc = OptionsSLEPc(
#      33     eps_tol=1e-10,
#      34     eps_target=0.0,
#    (...)
#      38     eps_which='smallest_real',
#      39 )
# ---> 40 u_solver = evp(helmholtz, bcs, slepc)(fs)
#      41 u_solver.solve()
#
# File ~/Desktop/LUCiFEx/lucifex/solver/pde.py:825, in EigenvalueProblem.from_forms_func.<locals>._create(*args, **kwargs)
#     821     if isinstance(solutions, (Function, FunctionSeries)):
#     822         solutions = solutions.function_space
#     823 return cls(
#     824     solutions,
# --> 825     forms_func(*args, **kwargs),
#     826     bcs,
#     827     slepc,
#     828     jit,
#     829     ffcx,
#     830     cache_matrix,
#     831     future,
#     832     overwrite,
#     833 )
#
# File ~/Desktop/LUCiFEx/lucifex/pde/eigen.py:31, in helmholtz(u, k, f, bcs)
#      29 else:
#      30     fs = u.function_space
# ---> 31 dx = Measure('dx', u.function_space.mesh)
#      32 v = TestFunction(fs)
#      33 u_trial = TrialFunction(fs)
#
# AttributeError: 'FunctionSpace' object has no attribute 'function_space'

# %%
sqrt = lambda x: np.sqrt(np.real(x)) if np.real(x) > 0 else None
k_values = [sqrt(e) for e in u_solver.eigenvalues]
k_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 sqrt = lambda x: np.sqrt(np.real(x)) if np.real(x) > 0 else None
# ----> 2 k_values = [sqrt(e) for e in u_solver.eigenvalues]
#       3 k_values
#
# NameError: name 'u_solver' is not defined

# %%
for k, u in zip(k_values, u_solver.eigenfunctions):
    if k is not None:
        fig, ax = plot_colormap(u, title=f'$k={k}$')
        write(fig, f'A16_helmholtz_k={k:.3f}', './figures', close=False, pickle=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for k, u in zip(k_values, u_solver.eigenfunctions):
#       2     if k is not None:
#       3         fig, ax = plot_colormap(u, title=f'$k={k}$')
#
# NameError: name 'k_values' is not defined
